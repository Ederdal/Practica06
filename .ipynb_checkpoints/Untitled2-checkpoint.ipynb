# %% [markdown]
# # Practica 06: Preparacion de Datos para su Analisis (ETL)

# %% [markdown]
# **Asignatura:** Extracción de Conocimiento en Bases de Datos
# Unidad 2: Preparación de los Datos
# PE: Ingeniería Desarrollo y Gestión de Software <br>
# Realizado por: **Edgar Cruz Salas**: - 220219

# %% [markdown]
# ## 1. Importacion de las librerias y paquetes a utilizar para el analisis de datos

# %%
# Práctica 06: Preparación de Datos para su Análisis (ETL)

# 1. Importación de las Librerías y Paquetes a utilizar para el análisis de datos.
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## 2. Ubicacion del origen de los datos

# %%
# !cd
# Out:
# C:\Users\52746\9A-IDGS\Practica 06

# %%
# !dir
# Out:
#  El volumen de la unidad C es Acer
#  El número de serie del volumen es: 2856-49D2
#
#  Directorio de C:\Users\52746\9A-IDGS\Practica 06
#
# 17/06/2025  10:59 p. m.    <DIR>          .
# 17/06/2025  10:59 p. m.    <DIR>          ..
# 17/06/2025  10:54 p. m.    <DIR>          .ipynb_checkpoints
# 17/06/2025  10:51 p. m.            21,739 Ejercicio1.ipynb
# 17/06/2025  10:59 p. m.            18,408 Ejercico2.ipynb
# 17/06/2025  10:56 p. m.             1,792 rick_and_morty_personajes.csv
# 17/06/2025  10:14 p. m.         4,127,778 salaries.csv
# 11/06/2025  08:47 a. m.           747,416 Untitled.ipynb
# 17/06/2025  10:52 p. m.           747,045 Untitled2.ipynb
#                6 archivos      5,664,178 bytes
#                3 dirs  21,540,982,784 bytes libres

# %% [markdown]
# ## 3. Construccion y consulta del dataframe

# %%
# Importación y acceso a un DataFrame (Matrix)
df = pd.read_csv("salaries.csv")

# %%
# Consultas básicas y metadatos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73167 entries, 0 to 73166
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           73155 non-null  float64
#  1   experience_level    73155 non-null  object
#  2   employment_type     73155 non-null  object
#  3   job_title           73150 non-null  object
#  4   salary              73152 non-null  float64
#  5   salary_currency     73153 non-null  object
#  6   salary_in_usd       73152 non-null  float64
#  7   employee_residence  73155 non-null  object
#  8   remote_ratio        73153 non-null  float64
#  9   company_location    73155 non-null  object
#  10  company_size        73155 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 6.1+ MB

# %%
# Cuantos registros tenemos? (tuplas, iterables)
df.size
# Out:
# 804837

# %%
print(len(df))
#Devuelve el total de tuplas o registros
# Out:
# 73167

# %% [markdown]
# Consultas Basicas sobre el Dataframe

# %%
df.head() #Devulvelos primeros 5 registros o tuplas de datos frame
# Out:
#    work_year experience_level employment_type           job_title    salary  \
# 0     2025.0               SE              FT  Data Product Owner  170000.0
# 1        NaN              NaN             NaN                 NaN       NaN
# 2        NaN              NaN             NaN                 NaN       NaN
# 3        NaN              NaN             NaN                 NaN       NaN
# 4        NaN              NaN             NaN                 NaN       NaN
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD       170000.0                 US           0.0
# 1             NaN            NaN                NaN           NaN
# 2             NaN            NaN                NaN           NaN
# 3             NaN            NaN                NaN           NaN
# 4             NaN            NaN                NaN           NaN
#
#   company_location company_size
# 0               US            M
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN

# %%
df.tail() ## Devuelve los ultimos datos del DataFrame, si no se especifica cuantos automaticamente devuelve los ultimos 5
# Out:
#        work_year experience_level employment_type                 job_title  \
# 73162     2020.0               SE              FT            Data Scientist
# 73163     2021.0               MI              FT  Principal Data Scientist
# 73164     2020.0               EN              FT            Data Scientist
# 73165     2020.0               EN              CT     Business Data Analyst
# 73166     2021.0               SE              FT            Data Scientist
#
#           salary salary_currency  salary_in_usd employee_residence  \
# 73162   412000.0             USD       412000.0                 US
# 73163   151000.0             USD       151000.0                 US
# 73164   105000.0             USD       105000.0                 US
# 73165   100000.0             USD       100000.0                 US
# 73166  7000000.0             INR        94665.0                 IN
#
#        remote_ratio company_location company_size
# 73162         100.0               US            L
# 73163         100.0               US            L
# 73164         100.0               US            S
# 73165         100.0               US            L
# 73166          50.0               IN            L

# %%
#Filas
print(len(df))
# Out:
# 73167

# %%
# Total de registros en el DataFrame
total_registros = len(df)
print(f"Total de registros: {total_registros}")
# Out:
# Total de registros: 73167

# %%
df.isnull() ## Mapea la matriz original con una matriz
# Out:
#        work_year  experience_level  employment_type  job_title  salary  \
# 0          False             False            False      False   False
# 1           True              True             True       True    True
# 2           True              True             True       True    True
# 3           True              True             True       True    True
# 4           True              True             True       True    True
# ...          ...               ...              ...        ...     ...
# 73162      False             False            False      False   False
# 73163      False             False            False      False   False
# 73164      False             False            False      False   False
# 73165      False             False            False      False   False
# 73166      False             False            False      False   False
#
#        salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0                False          False               False         False
# 1                 True           True                True          True
# 2                 True           True                True          True
# 3                 True           True                True          True
# 4                 True           True                True          True
# ...                ...            ...                 ...           ...
# 73162            False          False               False         False
# 73163            False          False               False         False
# 73164            False          False               False         False
# 73165            False          False               False         False
# 73166            False          False               False         False
#
#        company_location  company_size
# 0                 False         False
# 1                  True          True
# 2                  True          True
# 3                  True          True
# 4                  True          True
# ...                 ...           ...
# 73162             False         False
# 73163             False         False
# 73164             False         False
# 73165             False         False
# 73166             False         False
#
# [73167 rows x 11 columns]

# %%
df.notnull() ## Realiza un mapeo de la matriz original colocando valores bolaneos de acuerdo a la condicion de si es nulo
# Out:
#        work_year  experience_level  employment_type  job_title  salary  \
# 0           True              True             True       True    True
# 1          False             False            False      False   False
# 2          False             False            False      False   False
# 3          False             False            False      False   False
# 4          False             False            False      False   False
# ...          ...               ...              ...        ...     ...
# 73162       True              True             True       True    True
# 73163       True              True             True       True    True
# 73164       True              True             True       True    True
# 73165       True              True             True       True    True
# 73166       True              True             True       True    True
#
#        salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0                 True           True                True          True
# 1                False          False               False         False
# 2                False          False               False         False
# 3                False          False               False         False
# 4                False          False               False         False
# ...                ...            ...                 ...           ...
# 73162             True           True                True          True
# 73163             True           True                True          True
# 73164             True           True                True          True
# 73165             True           True                True          True
# 73166             True           True                True          True
#
#        company_location  company_size
# 0                  True          True
# 1                 False         False
# 2                 False         False
# 3                 False         False
# 4                 False         False
# ...                 ...           ...
# 73162              True          True
# 73163              True          True
# 73164              True          True
# 73165              True          True
# 73166              True          True
#
# [73167 rows x 11 columns]

# %% [markdown]
# ## 4. Limpieza de Datos previo al analisis

# %% [markdown]
# Eliminacion de datos duplicados

# %%
bf_sinduplicados = df.drop_duplicates()

print("Tamaño del DF original", len(df))

print("Tamaño del DF sin duplicados", len(bf_sinduplicados))

print("Registros/Tuplas eliminadas:", len(df) - len(bf_sinduplicados))
# Out:
# Tamaño del DF original 73167
# Tamaño del DF sin duplicados 34032
# Registros/Tuplas eliminadas: 39135

# %% [markdown]
# Importante: la eliminacion de duplicados debe realizarce con extremo cuidado sobre todo con datos agrupados o que no tienen una clave primaria o atributo identificador, por que existe el riesgo de alterar los resultados y tomar decisiones erradas.

# %% [markdown]
# Eliminar datos de registros con algun dato vacio en cualquier columna

# %%
bf_sinvacios = df.dropna()

print("Tamaño del DF original", len(df))

print("Tamaño del DF sin duplicados", len(bf_sinvacios))

print("Registros/Tuplas eliminadas:", len(df) - len(bf_sinvacios))
# Out:
# Tamaño del DF original 73167
# Tamaño del DF sin duplicados 73148
# Registros/Tuplas eliminadas: 19

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  73155.000000  7.315200e+04   73152.000000  73153.000000
# mean    2023.831194  1.625559e+05  158014.864501     21.581480
# std        0.477827  1.925729e+05   72504.066325     41.022037
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2024.000000  1.069575e+05  106890.000000      0.000000
# 50%     2024.000000  1.480000e+05  147500.000000      0.000000
# 75%     2024.000000  2.000000e+05  199700.000000      0.000000
# max     2025.000000  3.040000e+07  800000.000000    100.000000

# %%
df_sinsalary = df.dropna(subset=['salary'])

print("Tamaño del DF original", len(df))

print("Tamaño del DF sin duplicados", len(df_sinsalary))

print("Registros/Tuplas eliminadas:", len(df) - len(df_sinsalary))
# Out:
# Tamaño del DF original 73167
# Tamaño del DF sin duplicados 73152
# Registros/Tuplas eliminadas: 15

# %% [markdown]
# Reemplazar valores nulos con uno especifico

# %%
df_valoresdeSalarioSustituido = df.fillna(value = 'N/A')

# %% [markdown]
# Verificamos los nuevos datos

# %%
df_valoresdeSalarioSustituido
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0        2025.0               SE              FT        Data Product Owner
# 1           N/A              N/A             N/A                       N/A
# 2           N/A              N/A             N/A                       N/A
# 3           N/A              N/A             N/A                       N/A
# 4           N/A              N/A             N/A                       N/A
# ...         ...              ...             ...                       ...
# 73162    2020.0               SE              FT            Data Scientist
# 73163    2021.0               MI              FT  Principal Data Scientist
# 73164    2020.0               EN              FT            Data Scientist
# 73165    2020.0               EN              CT     Business Data Analyst
# 73166    2021.0               SE              FT            Data Scientist
#
#           salary salary_currency salary_in_usd employee_residence  \
# 0       170000.0             USD      170000.0                 US
# 1            N/A             N/A           N/A                N/A
# 2            N/A             N/A           N/A                N/A
# 3            N/A             N/A           N/A                N/A
# 4            N/A             N/A           N/A                N/A
# ...          ...             ...           ...                ...
# 73162   412000.0             USD      412000.0                 US
# 73163   151000.0             USD      151000.0                 US
# 73164   105000.0             USD      105000.0                 US
# 73165   100000.0             USD      100000.0                 US
# 73166  7000000.0             INR       94665.0                 IN
#
#       remote_ratio company_location company_size
# 0              0.0               US            M
# 1              N/A              N/A          N/A
# 2              N/A              N/A          N/A
# 3              N/A              N/A          N/A
# 4              N/A              N/A          N/A
# ...            ...              ...          ...
# 73162        100.0               US            L
# 73163        100.0               US            L
# 73164        100.0               US            S
# 73165        100.0               US            L
# 73166         50.0               IN            L
#
# [73167 rows x 11 columns]

# %% [markdown]
# Sustitucion de valores

# %%
df_valoresdeSalarioSustituido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73167 entries, 0 to 73166
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           73167 non-null  object
#  1   experience_level    73167 non-null  object
#  2   employment_type     73167 non-null  object
#  3   job_title           73167 non-null  object
#  4   salary              73167 non-null  object
#  5   salary_currency     73167 non-null  object
#  6   salary_in_usd       73167 non-null  object
#  7   employee_residence  73167 non-null  object
#  8   remote_ratio        73167 non-null  object
#  9   company_location    73167 non-null  object
#  10  company_size        73167 non-null  object
# dtypes: object(11)
# memory usage: 6.1+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73167 entries, 0 to 73166
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           73155 non-null  float64
#  1   experience_level    73155 non-null  object
#  2   employment_type     73155 non-null  object
#  3   job_title           73150 non-null  object
#  4   salary              73152 non-null  float64
#  5   salary_currency     73153 non-null  object
#  6   salary_in_usd       73152 non-null  float64
#  7   employee_residence  73155 non-null  object
#  8   remote_ratio        73153 non-null  float64
#  9   company_location    73155 non-null  object
#  10  company_size        73155 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 6.1+ MB

# %% [markdown]
# Que pasaria si con el nuevo DataFrame ejecuti un nuevo describe?

# %%
df_valoresdeSalarioSustituido.describe()
# Out:
#         work_year experience_level employment_type       job_title    salary  \
# count     73167.0            73167           73167           73167   73167.0
# unique        7.0                5               5             290    7097.0
# top        2024.0               SE              FT  Data Scientist  160000.0
# freq      62229.0            42930           72815           11443    1437.0
#
#        salary_currency  salary_in_usd employee_residence  remote_ratio  \
# count            73167        73167.0              73167       73167.0
# unique              26         7703.0                 94           4.0
# top                USD       160000.0                 US           0.0
# freq             69422         1426.0              65987       57225.0
#
#        company_location company_size
# count             73167        73167
# unique               87            5
# top                  US            M
# freq              66039        70537

# %% [markdown]
# Sustitucion de salarios null a 0.0

# %%
df_valoresdeSalarioSustituidoporCero = df.fillna({'salary': 0.0, 'salary_in_usd': 0.0})

# %%
df_valoresdeSalarioSustituidoporCero
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0         2025.0               SE              FT        Data Product Owner
# 1            NaN              NaN             NaN                       NaN
# 2            NaN              NaN             NaN                       NaN
# 3            NaN              NaN             NaN                       NaN
# 4            NaN              NaN             NaN                       NaN
# ...          ...              ...             ...                       ...
# 73162     2020.0               SE              FT            Data Scientist
# 73163     2021.0               MI              FT  Principal Data Scientist
# 73164     2020.0               EN              FT            Data Scientist
# 73165     2020.0               EN              CT     Business Data Analyst
# 73166     2021.0               SE              FT            Data Scientist
#
#           salary salary_currency  salary_in_usd employee_residence  \
# 0       170000.0             USD       170000.0                 US
# 1            0.0             NaN            0.0                NaN
# 2            0.0             NaN            0.0                NaN
# 3            0.0             NaN            0.0                NaN
# 4            0.0             NaN            0.0                NaN
# ...          ...             ...            ...                ...
# 73162   412000.0             USD       412000.0                 US
# 73163   151000.0             USD       151000.0                 US
# 73164   105000.0             USD       105000.0                 US
# 73165   100000.0             USD       100000.0                 US
# 73166  7000000.0             INR        94665.0                 IN
#
#        remote_ratio company_location company_size
# 0               0.0               US            M
# 1               NaN              NaN          NaN
# 2               NaN              NaN          NaN
# 3               NaN              NaN          NaN
# 4               NaN              NaN          NaN
# ...             ...              ...          ...
# 73162         100.0               US            L
# 73163         100.0               US            L
# 73164         100.0               US            S
# 73165         100.0               US            L
# 73166          50.0               IN            L
#
# [73167 rows x 11 columns]

# %%
df_valoresdeSalarioSustituidoporCero.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  73155.000000  7.316700e+04   73167.000000  73153.000000
# mean    2023.831194  1.625226e+05  157982.469802     21.581480
# std        0.477827  1.925672e+05   72531.922465     41.022037
# min     2020.000000  0.000000e+00       0.000000      0.000000
# 25%     2024.000000  1.068750e+05  106823.500000      0.000000
# 50%     2024.000000  1.480000e+05  147500.000000      0.000000
# 75%     2024.000000  2.000000e+05  199700.000000      0.000000
# max     2025.000000  3.040000e+07  800000.000000    100.000000

# %%
df['experience_level'].unique()
# Out:
# array(['SE', nan, 'EN', 'MI', 'EX'], dtype=object)

# %%
df['experience_level'].value_counts(dropna=False)
# Out:
# experience_level
# SE     42930
# MI     21852
# EN      6879
# EX      1494
# NaN       12
# Name: count, dtype: int64

# %%
valores_permitidos=['SE','EN','MI','EX',]
df_soloexperienciacorrecta=df[df['experience_level'].isin(valores_permitidos)]

# %%
df_soloexperienciacorrecta['experience_level'].value_counts(dropna=False)
# Out:
# experience_level
# SE    42930
# MI    21852
# EN     6879
# EX     1494
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Analisis Basico del DataFrame (Datos Estadisticos Generales)

# %% [markdown]
# Metodo que realiza un reporte de los valores estadisticos basicos (media, conteo, mediana, desciacion, estandar, valor maximo, valor minimo y la concentracion de frecuencia de 25%, 50%, 75% sobre los datos **Cuantitativos** excluyendo loa valores **cualitativos**)

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  73155.000000  7.315200e+04   73152.000000  73153.000000
# mean    2023.831194  1.625559e+05  158014.864501     21.581480
# std        0.477827  1.925729e+05   72504.066325     41.022037
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2024.000000  1.069575e+05  106890.000000      0.000000
# 50%     2024.000000  1.480000e+05  147500.000000      0.000000
# 75%     2024.000000  2.000000e+05  199700.000000      0.000000
# max     2025.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# ## 6. Definir los criterios de analisis (categorias)

# %%
analysis_criteria = ['work_year', 'experience_level', 'employment_type', 'job_title',
                'employee_residence', 'company_location', 'company_size']

# %% [markdown]
# ## 7. Graficamos algo Basico

# %% [markdown]
# Visualizacion general del Data Frame

# %%
df.hist(color='pink')
# El metodo hist
# Out:
# array([[<Axes: title={'center': 'work_year'}>,
#         <Axes: title={'center': 'salary'}>],
#        [<Axes: title={'center': 'salary_in_usd'}>,
#         <Axes: title={'center': 'remote_ratio'}>]], dtype=object)

# %%
Graficamos de una sola categoría cuantitativa, para este caso solo el año en que se recolectaron los datos con el trabajador('work_year')

# %%
# Aplicamos la limpieza necesaria sobre el data frame
df_limpio_graficacion = df.dropna(); # Eliminar nulos 
df_limpio_graficacion=df_limpio_graficacion[df_limpio_graficacion['experience_level'].isin(valores_permitidos)] # Elimina datos no permitidos
df_limpio_graficacion['experience_level'].value_counts(dropna=False) 

df_limpio_graficacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73148 entries, 0 to 73166
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           73148 non-null  float64
#  1   experience_level    73148 non-null  object
#  2   employment_type     73148 non-null  object
#  3   job_title           73148 non-null  object
#  4   salary              73148 non-null  float64
#  5   salary_currency     73148 non-null  object
#  6   salary_in_usd       73148 non-null  float64
#  7   employee_residence  73148 non-null  object
#  8   remote_ratio        73148 non-null  float64
#  9   company_location    73148 non-null  object
#  10  company_size        73148 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 6.7+ MB

# %%
df_limpio_graficacion.hist(column='work_year', color='pink')
# Out:
# array([[<Axes: title={'center': 'work_year'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

ax = df_limpio_graficacion.hist(column='work_year', color='pink')

ax = ax[0][0]

 for rect in ax.patches:
    height = rect.get_height()
    if height > 0:
        ax.text(rect.get_x() + rect.get_width()/2,  
                height + 500,                       
                str(int(height)),                   
                ha='center', va='bottom', fontsize=9)

plt.show()

# %%
def_color = 'pink'

for f in analysis_criteria:
    plt.figure(figsize=(12,3))
    df[f].value_counts().plot(kind='bar', color=def_color)
    plt.title(f)
    plt.grid()
    plt.show()

# %% [markdown]
# ## 8. Limpiamos los datos y solo nos enfocaremos en los datos recolectados desde el 2023, empleos de tiempo completo (Full time) en EU (US)

# %%
# Crearemos un subconjunto de la muestra original

df_after2023 = df[(df.work_year>=2023) & 
               (df.employment_type=='FT') & 
               (df.company_location=='US') &
               (df.salary_in_usd)]

# %% [markdown]
# Revisamos los datos metadatos de la nueva muestra

# %%
df_after2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64331 entries, 0 to 71267
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           64331 non-null  float64
#  1   experience_level    64331 non-null  object
#  2   employment_type     64331 non-null  object
#  3   job_title           64328 non-null  object
#  4   salary              64331 non-null  float64
#  5   salary_currency     64331 non-null  object
#  6   salary_in_usd       64331 non-null  float64
#  7   employee_residence  64331 non-null  object
#  8   remote_ratio        64331 non-null  float64
#  9   company_location    64331 non-null  object
#  10  company_size        64331 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 5.9+ MB

# %%
print(len(df_after2023))
# Out:
# 64331

# %%
print('Tamaño de la muestra:', df_after2023.shape)
features_cat_select=['experience_level',
                     'job_title',
                     'employee_residence',
                     'company_size',]
# Out:
# Tamaño de la muestra: (64331, 11)

# %%
## Algunas de las personas de nuestro subconjunto trabajan desde fuera del pais 
df_after2023.employee_residence.value_counts()
# Out:
# employee_residence
# US    64310
# AR        2
# UZ        2
# DE        2
# IN        2
# TR        1
# PT        1
# EG        1
# NG        1
# BE        1
# FR        1
# TN        1
# CA        1
# TH        1
# IT        1
# UG        1
# GE        1
# KW        1
# Name: count, dtype: int64

# %%
# Mostrar la distribucion de trabajo remoto
plt.figure(figsize=(3,7))
df_after2023.remote_ratio.value_counts().sort_index().plot(kind='bar')
plt.title('Distribución de Modal de Trabajo para las Empresas Estadounidenses')
plt.grid()
plt.show()

# %%
df_mexico = df[df['employee_residence']=='MX']

print(len(df_mexico))
# Out:
# 52

# %%
analysis_usd = ['salary_in_usd']

# %%
def_color = 'pink'

for f in analysis_usd:
    plt.figure(figsize=(12, 3))
    
    bins = [0, 100000, 250000, float('inf')]
    labels = ['0-100k', '100k-250k', '250k+']
    categorized = pd.cut(df[f], bins=bins, labels=labels)
    
    counts = categorized.value_counts().sort_index()
    
    ax = counts.plot(kind='bar', color=def_color)
    
    for i, v in enumerate(counts):
        ax.text(i, v + 0.5, str(v), ha='center', va='bottom', fontweight='bold')
    
    plt.title(f)
    plt.ylabel('Cantidad de personas')
    plt.xlabel('Rango de salario (USD)')
    plt.grid(axis='y')
    
    plt.show()
